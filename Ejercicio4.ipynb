# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipePosada9/Ejercicios_poo/blob/main/Ejercicio4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Te damos la bienvenida a Colab

# %%
# Ejercicio 4
# Felipe Posada

class Edades:
    def __init__(self, edad_juan):
        self.edad_juan = edad_juan
        self.edad_alberto = 0
        self.edad_ana = 0
        self.edad_mama = 0

    def calcular_edades(self):
        self.edad_alberto = (2 * self.edad_juan) / 3
        self.edad_ana = (4 * self.edad_juan) / 3
        self.edad_mama = self.edad_juan + self.edad_alberto + self.edad_ana

    def mostrar_edades(self):
        print("LAS EDADES SON:")
        print("ALBERTO:", self.edad_alberto)
        print("JUAN:", self.edad_juan)
        print("ANA:", self.edad_ana)
        print("MAMÁ:", self.edad_mama)

obj = Edades(9)
obj.calcular_edades()
obj.mostrar_edades()
# Out:
# LAS EDADES SON:
# ALBERTO: 6.0
# JUAN: 9
# ANA: 12.0
# MAMÁ: 27.0
